# %% [markdown]
# # Matplotlib Tutorial for Beginners

# %% [markdown]
# Hi Guys, Welcome to [Tirendaz Academy](https://youtube.com/c/tirendazacademy) 😀
# </br>
# In this notebook, I'm going to talk about Matplotlib.
# </br>
# Happy learning 🐱‍🏍

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <div id='5858c31f-1174-4e77-aa36-428facd15fbf'></div>

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
data=np.random.randn(50,).cumsum()

# %%
ax1.plot(data, 'k--')

# %%
ax2.plot(data, "r-")
ax3.plot(data, "b.")

# %% [markdown]
# ## Color, Markings, and Line Styles

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,14]

# %%
fig=plt.figure()
# Out:
# <div id='061ed9e0-0fde-4780-bcbb-e7639655f014'></div>

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
# Out:
# <div id='e72f3a15-464e-4b7c-9f22-1ebe7884b8a1'></div>

# %%
ax.plot(x, y, 'r--')

# %%
ax.plot(x, y, linestyle='--', color='r')

# %%
plt.plot?

# %%
plt.plot(data, 'ko--')

# %%
# %matplotlib inline

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data,
         'k-',
         drawstyle='steps-post',
         label='Stepwise')

# %%
plt.plot(data, 'k-',
         drawstyle='steps-post',
         label='Stepwise')
plt.legend(loc='best')

# %% [markdown]
# ## Thickness, Label and Legend

# %%
# %matplotlib notebook

# %%
fig=plt.figure()
# Out:
# <div id='150b5b62-a6d3-49f7-997d-d50f4bd1bb40'></div>

# %%
ax = fig.add_subplot(1, 1, 1)

# %%
ax.plot(data)

# %%
location=ax.set_xticks([0,10,20,30,40,50])
label=ax.set_xticklabels(
    ["one","two","three","four","five","six"],
    rotation=30,
    fontsize="small")

# %%
ax.set_title('First Graph')
# Out:
# Text(0.5, 1.0, 'First Graph')

# %%
ax.set_xlabel('Stages')
ax.set_ylabel('Anything')
# Out:
# Text(0, 0.5, 'Anything')

# %%
feature={"title":"Perfect Graph",
         "xlabel":"Steps",
         "ylabel":"Numbers"}

# %%
ax.set(**feature)
# Out:
# [Text(0.5, 1.0, 'Perfect Graph'),
#  Text(0.5, 0, 'Steps'),
#  Text(0, 0.5, 'Numbers')]

# %% [markdown]
# ## Adding Legends

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax=fig.add_subplot(1,1,1)

# %%
data1=np.random.randn(1000).cumsum()
data2=np.random.randn(1000).cumsum()
data3=np.random.randn(1000).cumsum()

# %%
ax.plot(data1, 'k', label='one')
ax.plot(data2, 'b--', label='two')
ax.plot(data3, 'r.', label='three')

# %%
ax.legend()

# %% [markdown]
# ## Annotations and Drawing on a Subplot

# %%
import pandas as pd

# %% [markdown]
# Let's import the data set now.

# %%
df=pd.read_csv('FB.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 1  2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2  2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 3  2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 4  2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#      Volume
# 0  65280800
# 1  40356500
# 2  34042100
# 3  32400000
# 4  24763400

# %%
df=pd.read_csv('FB.csv',
               index_col=0,
               parse_dates=True)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# 2018-08-02  32400000
# 2018-08-03  24763400

# %%
c_price=df["Close"]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c_price.plot(ax=ax, style='k-')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ax.set_title(
    'Facebook stock closing prices')
# Out:
# Text(0.5, 1.0, 'Facebook stock closing prices')

# %%
c_price.min()
# Out:
# 124.059998

# %%
c_price["2018-12-24"]
# Out:
# 124.059998

# %%
date="2018-12-24"
text="Minimum"

# %%
ax.annotate(
    text, xy=(date,125), xytext=(date,150),
    arrowprops=dict(facecolor='red'))
# Out:
# Text(2018-12-24, 150, 'Minimum')

# %% [markdown]
# ## Saving Plots to File

# %%
plt.savefig("my-graph.pdf")

# %%
plt.savefig("my-graph.png")

# %%
plt.savefig("my-graph.png", dpi=500)

# %%
plt.savefig("my-graph.png",
            dpi=500,
            bbox_inches="tight")

# %%
# !git clone https://github.com/Xiaoxiao-teacher/Data-Visualization-with-Python
# Out:
# Cloning into 'Data-Visualization-with-Python'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 150 (delta 67), reused 65 (delta 13), pack-reused 0
# Receiving objects: 100% (150/150), 22.67 MiB | 28.69 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %% [markdown]
# Don't forget to follow us on [YouTube](http://youtube.com/tirendazacademy) | [Medium](http://tirendazacademy.medium.com) | [Twitter](http://twitter.com/tirendazacademy) | [GitHub](http://github.com/tirendazacademy) | [Linkedin](https://www.linkedin.com/in/tirendaz-academy) | [Kaggle](https://www.kaggle.com/tirendazacademy) 😎
