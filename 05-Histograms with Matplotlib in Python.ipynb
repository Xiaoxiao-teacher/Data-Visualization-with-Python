# %% [markdown]
# # Histograms with Matplotlib in Python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## How to Plot Histograms ?

# %%
data=np.random.randn(1000)

# %%
plt.hist(data)
# Out:
# (array([  2.,   1.,  25., 112., 222., 311., 214.,  81.,  28.,   4.]),
#  array([-4.10114989, -3.34771369, -2.59427748, -1.84084128, -1.08740508,
#         -0.33396888,  0.41946733,  1.17290353,  1.92633973,  2.67977593,
#          3.43321213]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
plt.hist(data, edgecolor="black")
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
plt.hist(data, edgecolor="black", bins=10)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
bins=[-3,-2,-1,0,1,2,3]

# %%
plt.hist(data, edgecolor="black", bins=bins)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
median=np.median(data)

# %%
plt.hist(data, edgecolor="black", bins=bins)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.axvline(median, color="red")

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-3, 2, 1000)
x3 = np.random.normal(2, 1, 1000)

# %%
plt.hist(x1, histtype="stepfilled",
         alpha=0.5, bins=40)
plt.hist(x2, histtype="stepfilled",
         alpha=0.5, bins=40)
plt.hist(x3, histtype="stepfilled",
         alpha=0.5, bins=40)
# Out:
# (array([ 2.,  4.,  2.,  2.,  8.,  7.,  3.,  8., 12., 13., 17., 30., 28.,
#         31., 40., 37., 38., 36., 57., 45., 67., 63., 56., 44., 52., 49.,
#         34., 39., 36., 28., 35., 17., 17.,  7., 12.,  7.,  6.,  3.,  6.,
#          2.]),
#  array([-1.01639112, -0.87388134, -0.73137156, -0.58886178, -0.446352  ,
#         -0.30384222, -0.16133244, -0.01882266,  0.12368712,  0.2661969 ,
#          0.40870668,  0.55121646,  0.69372623,  0.83623601,  0.97874579,
#          1.12125557,  1.26376535,  1.40627513,  1.54878491,  1.69129469,
#          1.83380447,  1.97631425,  2.11882403,  2.26133381,  2.40384359,
#          2.54635337,  2.68886315,  2.83137293,  2.97388271,  3.11639249,
#          3.25890226,  3.40141204,  3.54392182,  3.6864316 ,  3.82894138,
#          3.97145116,  4.11396094,  4.25647072,  4.3989805 ,  4.54149028,
#          4.68400006]),
#  [<matplotlib.patches.Polygon at 0x7b2006f2e440>])

# %% [markdown]
# ## Application with real data set

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/Xiaoxiao-teacher/Data-Visualization-with-Python/main/Datasets/imdbratings.txt")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
plt.hist(movies.duration)
# Out:
# (array([ 25., 168., 301., 259., 111.,  66.,  27.,  14.,   5.,   3.]),
#  array([ 64. ,  81.8,  99.6, 117.4, 135.2, 153. , 170.8, 188.6, 206.4,
#         224.2, 242. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(
    movies.duration, edgecolor="black", color="m")
# Out:
# (array([ 25., 168., 301., 259., 111.,  66.,  27.,  14.,   5.,   3.]),
#  array([ 64. ,  81.8,  99.6, 117.4, 135.2, 153. , 170.8, 188.6, 206.4,
#         224.2, 242. ]),
#  <BarContainer object of 10 artists>)

# %%
bins=np.arange(70,200,10)

# %%
plt.hist(movies.duration, edgecolor="black",
         color="m", bins=bins)
plt.xticks(bins)
# Out:
# ([<matplotlib.axis.XTick at 0x7b200510ae90>,
#   <matplotlib.axis.XTick at 0x7b200510ae60>,
#   <matplotlib.axis.XTick at 0x7b200510ad70>,
#   <matplotlib.axis.XTick at 0x7b200516c310>,
#   <matplotlib.axis.XTick at 0x7b200516cdc0>,
#   <matplotlib.axis.XTick at 0x7b200516d870>,
#   <matplotlib.axis.XTick at 0x7b200516e320>,
#   <matplotlib.axis.XTick at 0x7b200516d420>,
#   <matplotlib.axis.XTick at 0x7b200516ed40>,
#   <matplotlib.axis.XTick at 0x7b200516f7f0>,
#   <matplotlib.axis.XTick at 0x7b20051902e0>,
#   <matplotlib.axis.XTick at 0x7b2005190d90>,
#   <matplotlib.axis.XTick at 0x7b200516de70>],
#  [Text(70, 0, '70'),
#   Text(80, 0, '80'),
#   Text(90, 0, '90'),
#   Text(100, 0, '100'),
#   Text(110, 0, '110'),
#   Text(120, 0, '120'),
#   Text(130, 0, '130'),
#   Text(140, 0, '140'),
#   Text(150, 0, '150'),
#   Text(160, 0, '160'),
#   Text(170, 0, '170'),
#   Text(180, 0, '180'),
#   Text(190, 0, '190')])

# %%
plt.hist(movies.duration, edgecolor="black",
         color="m", bins=bins)
plt.xticks(bins)
plt.title("Histograms of movie durations in imdb")
plt.xlabel("Durations")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')
