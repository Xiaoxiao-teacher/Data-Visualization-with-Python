# %% [markdown]
# # Introduction to Matplotlib
#
#
# ## Matplotlib Install

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)

# %% [markdown]
# ## Interactive Graphics

# %%
plt.plot(data)

# %%
plt.title("interactive test")
# Out:
# Text(0.5, 1.0, 'interactive test')

# %%
plt.xlabel("sample name")
# Out:
# Text(0.5, 0, 'sample name')

# %% [markdown]
# ## Static Graphics

# %%
x=[1,2,3,4]
y=[1,4,9,16]

plt.plot(x,y)

# %%
d=np.arange(0.,5.,0.2)

# %%
plt.plot(d, d,'r--',d,d**2,'bs',d,d**3,'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x7f79482f8610>,
#  <matplotlib.lines.Line2D at 0x7f79482f84f0>,
#  <matplotlib.lines.Line2D at 0x7f79482f85e0>]

# %% [markdown]
# ## Save the Graph

# %%
plt.savefig('my-graph.png')
